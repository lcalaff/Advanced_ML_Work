# %% [markdown]
# ## Kaggle Week 4 Analysis
# Lucas Calaff
# 04/29/26

# %% [markdown]
# ## Link to latest Notebook:
# https://github.com/lcalaff/Advanced_ML_Work/blob/main/Git_Code/Kaggle%20Homework%20Lucas%20lucascalaff206/Stacking_Kaggle_HW4.ipynb

# %% [markdown]
# ## Analysis

# %% [markdown]
# 1. I used 4 different models to try and create the ultimate metalearner, these were XGBoost, RandomForest, LightGBM, and HGBoost. These were all tested indivdually at first to see how they perform on their own.
#
# 2. I also Engineered some features to try and develope better features to use in the model, which edned up being around 34, however i condense my features to 20 highlighting only the ones that were the most important for these predictions.
#
# 3. The next step to my analysis was to figure out which of the models i was going to use and how to weight each of these models in order to obtain enough infomation to be able to have solid predictions. i first used a stacked ensemble model which took all 4 models and predicted irrigation.
#
# 4. The winning model was a probability abverageing ensemble, which compared if we were to use equal weights on the model or use a weight based on probabilities to try and see if a model had more predictablility over the other one. Using 4 models to do this made the weights fairly simmilar and also the fact that most of these models are basic boosting so predictions did not change a whole lot as weve seen in the kaggle between boosting models.
#
# 5. Tuned XGBoosting was a close second with a balanced accuracy of 0.9725, but the overall winner was OOF Stacking Meta learner, with a balanced accuracy score of 0.9733, which is a significant enough winner to use as our prediction models we submitted.
#
# 6. an important implication that i want to advise on is the fact that we are using 4 different models, which means that overfitting is highly likely. future modeling i would like to limit the meta learner to 2-3 unique models, that have very different algorythms to gain a stronger Model weight for the best model, help train that ensemble model to perform better.

# %%
from IPython.display import Image

Img1 = Image(filename = r"C:\Users\ldcal\OneDrive\Desktop\Cal Poly Courses\Spring\GSB-S545\Advanced_ML_Work\Git_Code\Kaggle Homework Lucas lucascalaff206\Screenshot 2026-04-29 173300.png")

display(Img1)

# %% [markdown]
# - One final note is that this was by far the biggest change in score that ive gotten during this competition, showing how powerful this ensemble model is in the irrigation prediction challenge, i will be intrested in seeing where i stand on the leaderboard when the final change up happens and if my model overfitted to learn about what i can do better in the future when it comes to these find of classification problems.
