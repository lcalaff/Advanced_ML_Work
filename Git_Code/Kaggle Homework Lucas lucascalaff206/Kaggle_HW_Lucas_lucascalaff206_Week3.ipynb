# %% [markdown]
# # MarkDown Notebook for Kaggle HW Week 3

# %% [markdown]
# ## 1. Links To Gradient Boosting Notebooks

# %% [markdown]
# https://github.com/lcalaff/Advanced_ML_Work/blob/main/Git_Code/Kaggle%20Homework%20Lucas%20lucascalaff206/Gradient%20Boosting%20Model.ipynb

# %% [markdown]
# https://github.com/lcalaff/Advanced_ML_Work/blob/main/Git_Code/Kaggle%20Homework%20Lucas%20lucascalaff206/LightGBM%20Boosting%20Model.ipynb

# %% [markdown]
# ## 2. Discussing Modeling Approaches

# %% [markdown]
# - The starting model that i tried was through sklearns base model gradientboostingclassifier and this did not perform as well as i had hoped and took a very lomg time to tune, making it note as desireable to move forward with in the predictions
# - the second model i tried was histagradient boosting and this was much better taking just seconds to fully run and outputting a better result.
# - my third model i tried was lightgbm and this model was also very fast while having many different features to tune for, a future refrence is that i saw various models that used lightgbm for the kaggle compention and i believe is a strong model tnat i should research futher for predictions.

# %% [markdown]
# - The modeling imporvements were very small however every bit that i improved was significant for my predictions and learning how these models worked can help me better understand how i can utilize them in the future.

# %% [markdown]
# Original HGBC F1 Score: 0.9831129416837849
# Best HGBC F1 Score: 0.9840390204834835
# Improvement in F1 Score: 0.0009260787996985265

# %% [markdown]
# Initial F1 Score: 0.9833
# Final F1 Score: 0.9836
# Improvement in F1 Score: 0.0003

# %% [markdown]
# - looking at f1 scores we can see taht the HistaGradient performes slightly better, one this to be aware of with this is how close to 1 the score is, indicating the possiblity that their was some data leakage. Seeing this alongside the leaderbaord score also shows that my training data is overpredicting, which should be expected but understanding why that is will be important for future research.

# %%
from IPython.display import Image

image1 = Image(filename = r"C:\Users\ldcal\OneDrive\Desktop\Cal Poly Courses\Spring\GSB-S545\Advanced_ML_Work\Git_Code\Kaggle Homework Lucas lucascalaff206\Screenshot 2026-04-21 161300.png")

display(image1)

# %% [markdown]
# As we can see through the submissions the two new models we used to make predictions with helped improve our score overall, indicating that these models are improtant to use in the future and couold even be combined to take the best methods from each of them to make an ensemble.
