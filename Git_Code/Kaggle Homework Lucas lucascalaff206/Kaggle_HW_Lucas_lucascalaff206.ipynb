# %% [markdown]
# ## 1.	3-4 Notebooks I found insightful towards my own analysis
#
# a.	https://www.kaggle.com/code/lalit7881/predicting-irrigation-need-eda#Heatmap
# My reasoning for choosing this notebook was I liked the heatmap comparing features to each other. This allowed for me to understand what features are linked to one another and support my reasoning when developing my own EDA.
#
# b.	https://www.kaggle.com/code/alsomostafiz/complete-eda-catboost#%F0%9F%94%81-11-%C2%B7-Cross%E2%80%91Validation-&-OOF-Predictions
# After doing an initial search on the notebooks and code page of this Kaggle competition, one thing I noticed was that a lot of people are implementing a CatBoost methodology that is performing really well. This approach is something that I could easily implement once I get a basic understanding for how boosting performs on the data set and can compare with methods we have learned throughout the class. I also appreciate the way this notebook is organized making it very easy to follow.
#
# c.	https://www.kaggle.com/code/chovyxu/playgrounds2026-ep4-neural-network#Decision-Tree-Binning
# This is an example of a way to make a bagging tree model more unique by introducing binning, this method that is being implemented in the model highlights explainability which is crucial for real world applications. I like that this notebook provides lots of explanations to what the code is doing on the dataset.

# %% [markdown]
# ## 2.	Link to EDA Notebook
# a.	https://github.com/lcalaff/Advanced_ML_Work/blob/main/Git_Code/Kaggle%20Homework%20Lucas%20lucascalaff206/EDA%20Notebook.ipynb

# %% [markdown]
# ## 3.	Link to Bagging & Boosting Notebook
# a.	https://github.com/lcalaff/Advanced_ML_Work/blob/main/Git_Code/Kaggle%20Homework%20Lucas%20lucascalaff206/Kaggle%20Bagging%20Notebook.ipynb
#
# b.	https://github.com/lcalaff/Advanced_ML_Work/blob/main/Git_Code/Kaggle%20Homework%20Lucas%20lucascalaff206/Kaggle%20Boosting%20Notebook.ipynb

# %% [markdown]
# ## 4.	Discussion of Bagging vs Boosting
#
# Throughout the time I spent making these predictive models one thing was pretty clear, tuning hyperparameters is going to take a lot of computing and time to get done, meaning that choosing the right ones to tune is even more important for future predictions.
#
# The bagging model did not have a lot of different models that I could test to see how performance did, the main thing I did was tune and CV for various parameters, which to my surprise did not perform as well as I thought they would . Researching the right parameters to use in the future may help me better improve on my models.
# One thing overall that I found difficult was learning how predictive modeling changes when there are 3 categories that we are predicting for instead of the typical classification questions that involve 2. This meant that I had to pay extra close attention to what my models were doing and understand how to encode my data so that I could make predictions in the first place.
#
# The boosting models had a lot more steps that I anticipated and I needed to gasp an understanding for what my models were doing and how my features needed to be changed in order to make predictions. One thing I noticed was tuning took much longer for these boosting models, indicating that they are much more in-depth algorithms that the bagging models I used. Using cat boost was a cool model to work with as there was very little I needed to do prior to running the model.

# %%
from IPython.display import Image

image1 = Image(filename= r'C:\Users\ldcal\OneDrive\Desktop\Cal Poly Courses\Spring\GSB-S545\Advanced_ML_Work\Git_Code\Kaggle Homework Lucas lucascalaff206\Screenshot 2026-04-15 181011.png')
image2 = Image(filename= r'C:\Users\ldcal\OneDrive\Desktop\Cal Poly Courses\Spring\GSB-S545\Advanced_ML_Work\Git_Code\Kaggle Homework Lucas lucascalaff206\Screenshot 2026-04-15 181032.png')

display(image1)
display(image2)

# %% [markdown]
# ## 5.	Improving Model Performance
# For future work one thing I would like to do is really dive into how I can make interactions and feature engineering different features to help improve predictability. During my EDA I noticed a new term that could be joined so doing that for future submissions might improve my predictability. Another aspect that I did not anticipate but will be noting for future submissions is that these models are going to take more time to run and more than a few hours to run these models is crucial for improving those hyperparameters. I would also like to test other boosting models to gauge how they stack up to see which models I approach different predictions with.
