# %% [markdown]
# # EDA Notebook

# %%
import pandas as pd
import numpy as np
import sweetviz as sv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Irrigation = pd.read_csv('train.csv')
report = sv.analyze(Irrigation)
report.show_html('Irrigation_EDA_Report.html')
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report Irrigation_EDA_Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# Looking at the mean values and standard deviations of soil ph by soil type
soil_ph_by_type = Irrigation.groupby('Soil_Type')['Soil_pH'].agg(['mean', 'std'])
print(soil_ph_by_type)
# Out:
#                mean       std
# Soil_Type
# Clay       6.484046  0.924186
# Loamy      6.485210  0.919383
# Sandy      6.484006  0.923315
# Silt       6.476298  0.923063

# %%
# Looking into soil moisture levels by soil type
soil_moisture_by_type = Irrigation.groupby('Soil_Type')['Soil_Moisture'].agg(['mean', 'std'])
print(soil_moisture_by_type)
# Out:
#                 mean        std
# Soil_Type
# Clay       37.393083  16.434517
# Loamy      37.574972  16.232677
# Sandy      36.924150  16.477929
# Silt       37.351386  16.346251

# %%
# Looking into temprature levels by soil type
temperature_by_type = Irrigation.groupby('Soil_Type')['Temperature_C'].agg(['mean', 'std'])
print(temperature_by_type)
# Out:
#                 mean       std
# Soil_Type
# Clay       26.997308  8.622698
# Loamy      26.790585  8.606294
# Sandy      27.104072  8.622293
# Silt       27.098990  8.640443

# %%
# value count of regions 
print(Irrigation['Region'].value_counts())
# Out:
# Region
# South      134809
# West       131189
# East       126163
# Central    123712
# North      114127
# Name: count, dtype: int64

# %% [markdown]
# ## Distributions of soil types by numerical features analysis

# %%
# Showing how each regions soil type is distributed
plt.figure(figsize=(10, 6))
sns.countplot(data=Irrigation, x='Region', hue='Soil_Type')
plt.title('Distribution of Soil Types by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.legend(title='Soil Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ## Soil types by region analysis

# %%
# look at irrigation need by soil type, irrigation is categorical so we can look at the distribution of irrigation needs by soil type
plt.figure(figsize=(10, 6))
sns.countplot(data=Irrigation, x='Soil_Type', hue='Irrigation_Need')
plt.title('Distribution of Irrigation Needs by Soil Type')
plt.xlabel('Soil Type')
plt.ylabel('Count')
plt.legend(title='Irrigation Need')
plt.show()

# %% [markdown]
# ## irrigation need by soil type analysis

# %%
# Look at irrigation need by region 
plt.figure(figsize=(10, 6))
sns.countplot(data=Irrigation, x='Region', hue='Irrigation_Need')
plt.title('Distribution of Irrigation Needs by Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.legend(title='Irrigation Need')
plt.show()

# %% [markdown]
# ## irrigation need by region analysis

# %%
# making a heatmazp to observe the correlation between numerical features

numerical_columns = Irrigation.select_dtypes(include=[np.number]).columns.tolist()
correlation_matrix = Irrigation[numerical_columns].corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='icefire', fmt='.2f')
plt.title('Correlation Matrix of Numerical Features')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ## heatmap of numerical features analysis
